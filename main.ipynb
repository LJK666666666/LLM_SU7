# %%
# !python src/train_comment_predictor.py --model ngboost
# Out:
# ...
# 【训练模型: ngboost】
# ...
# 特征: ['用户总评论数', '用户是否认证', '是否一级评论', '微博评论数', '发布小时', '发布星期', '是否工作日']
# 标签: 子评论数
# ...
# 【加载数据】
# ...
# 训练集: 217,162 条
# 验证集: 27,145 条
# 测试集: 27,145 条
#
# 【准备特征】
# 训练集特征形状: (217162, 7)
# 验证集特征形状: (27145, 7)
# 测试集特征形状: (27145, 7)
#
# 模型: NGBoost
#
# 【训练中...】
# 训练完成!
#
# 【评估结果】
#
# 数据集      RMSE       MAE        MSLE       R2
# --------------------------------------------------
# 训练集      9.6264     0.8370     0.0200     0.4128
# 验证集      10.6007    0.9674     0.0299     0.0371
# 测试集      16.2065    1.1504     0.0348     0.0340
#
# 数据集      ACP@20%      ACP@50%
# -----------------------------------
# 训练集      98.01       % 98.06       %
# 验证集      97.65       % 97.66       %
# 测试集      97.53       % 97.54       %
#
# 【不确定性估计】
# 数据集      NLL          LogNLL       PICP@95%     MPIW
# -------------------------------------------------------
# 训练集      -2.5689      -3.5247      96.80       % 43643566496863.1250
# 验证集      0.6329       -0.3450      95.03       % 4303608230537.3159
# ...

# %%
# !git clone https://huggingface.co/BAAI/bge-base-zh-v1.5

# %%
# !python src/train_comment_predictor.py --model ngboost --features all
# Out:
# ...
# 【训练模型: ngboost】
# ...
# 特征组: ['base', 'text', 'lda', 'density']
# 特征列 (17个): ['用户总评论数', '用户是否认证', '是否一级评论', '微博评论数', '发布小时', '发布星期', '是否工作日', '评论长度', '感叹号数', '问号数', '表情数', '话题标签有无', '小米相关词数', '主题', '时间顺序索引', '最大相似度', '重复次数']
# 标签: 子评论数
# ...
# 【加载数据】
# ...
# 训练集: 217,162 条
# 验证集: 27,145 条
# 测试集: 27,145 条
#   LDA特征已加载
#   时间密度特征已加载 (method=minhash)
#
# 【特征工程】
#   提取时间特征...
#   提取文本特征...
#   合并外部特征...
#
# 【准备特征】
# 训练集特征形状: (217162, 17)
# 验证集特征形状: (27145, 17)
# 测试集特征形状: (27145, 17)
#
# 模型: NGBoost
#
# 【训练中...】
# 训练完成!
#
# 【评估结果】
#
# 数据集      RMSE       MAE        MSLE       R2
# --------------------------------------------------
# 训练集      7.4147     0.7871     0.0179     0.6516
# 验证集      9.7197     0.9554     0.0283     0.1905
# 测试集      16.3682    1.1477     0.0347     0.0146
#
# 数据集      ACP@20%      ACP@50%
# -----------------------------------
# 训练集      98.15       % 98.22       %
# 验证集      97.61       % 97.62       %
# 测试集      97.61       % 97.61       %
#
# 【不确定性估计】
# ...

# %%
# !python src/train_comment_predictor.py --model bge_nn --epochs 1 --batch_size 32

# %%
# !python -m src --model xgboost --features all
# Out:
# ...
# 【训练模型: xgboost】
# ...
# 特征组: ['base', 'text', 'lda', 'density']
# 特征列 (17个): ['用户总评论数', '用户是否认证', '是否一级评论', '微博评论数', '发布小时', '发布星期', '是否工作日', '评论长度', '感叹号数', '问号数', '表情数', '话题标签有无', '小米相关词数', '主题', '时间顺序索引', '最大相似度', '重复次数']
# 标签: 子评论数
#
# 【特征工程】
#   提取时间特征...
#   提取文本特征...
#   合并外部特征...
#
# 【准备特征】
# 训练集特征形状: (217162, 17)
# 验证集特征形状: (27145, 17)
# 测试集特征形状: (27145, 17)
#
# 模型: XGBoost
#
# 【训练中...】
# 训练完成!
#
# 【评估结果】
#
# 数据集      RMSE       MAE        MSLE       R2
# --------------------------------------------------
# 训练集      9.4728     0.8201     0.0187     0.4314
# 验证集      10.2996    0.9542     0.0280     0.0910
# 测试集      16.3337    1.1377     0.0340     0.0187
#
# 数据集      ACP@20%      ACP@50%
# -----------------------------------
# 训练集      98.15       % 98.21       %
# 验证集      97.71       % 97.73       %
# 测试集      97.75       % 97.76       %
# 模型已保存: d:\010_CodePrograms\L\LLM_su7\results\comment_pred_xgboost_1\model.pkl
# ...

# %%
# !python -m src --model bge_mini --epochs 30 --batch_size 1024

# %%
# !python -m src --model ridge --features all
# Out:
# ...
# 【训练+测试 - 模型: ridge】
# ...
# 特征组: ['base', 'text', 'lda', 'density']
# 特征列 (17个): ['用户总评论数', '用户是否认证', '是否一级评论', '微博评论数', '发布小时', '发布星期', '是否工作日', '评论长度', '感叹号数', '问号数', '表情数', '话题标签有无', '小米相关词数', '主题', '时间顺序索引', '最大相似度', '重复次数']
# 标签: 子评论数
#
# 【特征工程】
#   提取时间特征...
#   提取文本特征...
#   合并外部特征...
#
# 【准备特征】
# 训练集特征形状: (217162, 17)
# 验证集特征形状: (27145, 17)
# 测试集特征形状: (27145, 17)
#
# 模型: Ridge
#
# 【训练中...】
# 训练完成!
#
# 【评估结果】
#
# 数据集      RMSE       MAE        MSLE       R2
# --------------------------------------------------
# 训练集      12.5430    1.0536     0.0310     0.0031
# 验证集      10.7807    1.0454     0.0315     0.0041
# 测试集      16.4740    1.2221     0.0365     0.0018
#
# 数据集      ACP@20%      ACP@50%
# -----------------------------------
# 训练集      97.94       % 97.94       %
# 验证集      97.82       % 97.82       %
# 测试集      97.83       % 97.83       %
# 模型已保存: d:\010_CodePrograms\L\LLM_su7\results\comment_pred_ridge_1\model.pkl
# ...

# %%
# !python -m src --model lasso --features all
# Out:
# ...
# 【训练+测试 - 模型: lasso】
# ...
# 特征组: ['base', 'text', 'lda', 'density']
# 特征列 (17个): ['用户总评论数', '用户是否认证', '是否一级评论', '微博评论数', '发布小时', '发布星期', '是否工作日', '评论长度', '感叹号数', '问号数', '表情数', '话题标签有无', '小米相关词数', '主题', '时间顺序索引', '最大相似度', '重复次数']
# 标签: 子评论数
#
# 【特征工程】
#   提取时间特征...
#   提取文本特征...
#   合并外部特征...
#
# 【准备特征】
# 训练集特征形状: (217162, 17)
# 验证集特征形状: (27145, 17)
# 测试集特征形状: (27145, 17)
#
# 模型: Lasso
#
# 【训练中...】
# 训练完成!
#
# 【评估结果】
#
# 数据集      RMSE       MAE        MSLE       R2
# --------------------------------------------------
# 训练集      12.5646    1.0427     0.0323     -0.0003
# 验证集      10.8052    1.0364     0.0329     -0.0004
# 测试集      16.4945    1.2126     0.0379     -0.0007
#
# 数据集      ACP@20%      ACP@50%
# -----------------------------------
# 训练集      97.91       % 97.91       %
# 验证集      97.77       % 97.77       %
# 测试集      97.80       % 97.80       %
# 模型已保存: d:\010_CodePrograms\L\LLM_su7\results\comment_pred_lasso_1\model.pkl
# ...

# %%
# !python -m src --model rf --features all
# Out:
# ...
# 【训练+测试 - 模型: rf】
# ...
# 特征组: ['base', 'text', 'lda', 'density']
# 特征列 (17个): ['用户总评论数', '用户是否认证', '是否一级评论', '微博评论数', '发布小时', '发布星期', '是否工作日', '评论长度', '感叹号数', '问号数', '表情数', '话题标签有无', '小米相关词数', '主题', '时间顺序索引', '最大相似度', '重复次数']
# 标签: 子评论数
#
# 【特征工程】
#   提取时间特征...
#   提取文本特征...
#   合并外部特征...
#
# 【准备特征】
# 训练集特征形状: (217162, 17)
# 验证集特征形状: (27145, 17)
# 测试集特征形状: (27145, 17)
#
# 模型: RandomForest
#
# 【训练中...】
# 训练完成!
#
# 【评估结果】
#
# 数据集      RMSE       MAE        MSLE       R2
# --------------------------------------------------
# 训练集      11.4217    0.9275     0.0256     0.1734
# 验证集      10.4883    0.9533     0.0289     0.0574
# 测试集      16.4190    1.1379     0.0347     0.0085
#
# 数据集      ACP@20%      ACP@50%
# -----------------------------------
# 训练集      97.99       % 98.01       %
# 验证集      97.78       % 97.80       %
# 测试集      97.79       % 97.79       %
# 模型已保存: d:\010_CodePrograms\L\LLM_su7\results\comment_pred_rf_1\model.pkl
# ...

# %%
# !python -m src --model gbdt --features all
# Out:
# ...
# 【训练+测试 - 模型: gbdt】
# ...
# 特征组: ['base', 'text', 'lda', 'density']
# 特征列 (17个): ['用户总评论数', '用户是否认证', '是否一级评论', '微博评论数', '发布小时', '发布星期', '是否工作日', '评论长度', '感叹号数', '问号数', '表情数', '话题标签有无', '小米相关词数', '主题', '时间顺序索引', '最大相似度', '重复次数']
# 标签: 子评论数
#
# 【特征工程】
#   提取时间特征...
#   提取文本特征...
#   合并外部特征...
#
# 【准备特征】
# 训练集特征形状: (217162, 17)
# 验证集特征形状: (27145, 17)
# 测试集特征形状: (27145, 17)
#
# 模型: GBDT
#
# 【训练中...】
# 训练完成!
#
# 【评估结果】
#
# 数据集      RMSE       MAE        MSLE       R2
# --------------------------------------------------
# 训练集      7.5990     0.7835     0.0172     0.6341
# 验证集      9.6232     0.9571     0.0282     0.2065
# 测试集      16.4058    1.1506     0.0347     0.0101
#
# 数据集      ACP@20%      ACP@50%
# -----------------------------------
# 训练集      98.17       % 98.25       %
# 验证集      97.70       % 97.72       %
# 测试集      97.67       % 97.68       %
# 模型已保存: d:\010_CodePrograms\L\LLM_su7\results\comment_pred_gbdt_1\model.pkl
# ...

# %%
# !python -m src --model xgboost --features all
# Out:
# ...
# 【训练+测试 - 模型: xgboost】
# ...
# 特征组: ['base', 'text', 'lda', 'density']
# 特征列 (17个): ['用户总评论数', '用户是否认证', '是否一级评论', '微博评论数', '发布小时', '发布星期', '是否工作日', '评论长度', '感叹号数', '问号数', '表情数', '话题标签有无', '小米相关词数', '主题', '时间顺序索引', '最大相似度', '重复次数']
# 标签: 子评论数
#
# 【特征工程】
#   提取时间特征...
#   提取文本特征...
#   合并外部特征...
#
# 【准备特征】
# 训练集特征形状: (217162, 17)
# 验证集特征形状: (27145, 17)
# 测试集特征形状: (27145, 17)
#
# 模型: XGBoost
#
# 【训练中...】
# 训练完成!
#
# 【评估结果】
#
# 数据集      RMSE       MAE        MSLE       R2
# --------------------------------------------------
# 训练集      9.4728     0.8201     0.0187     0.4314
# 验证集      10.2996    0.9542     0.0280     0.0910
# 测试集      16.3337    1.1377     0.0340     0.0187
#
# 数据集      ACP@20%      ACP@50%
# -----------------------------------
# 训练集      98.15       % 98.21       %
# 验证集      97.71       % 97.73       %
# 测试集      97.75       % 97.76       %
# 模型已保存: d:\010_CodePrograms\L\LLM_su7\results\comment_pred_xgboost_2\model.pkl
# ...

# %%
# !python -m src --model lightgbm --features all
# Out:
# ...
# 【训练+测试 - 模型: lightgbm】
# ...
# 特征组: ['base', 'text', 'lda', 'density']
# 特征列 (17个): ['用户总评论数', '用户是否认证', '是否一级评论', '微博评论数', '发布小时', '发布星期', '是否工作日', '评论长度', '感叹号数', '问号数', '表情数', '话题标签有无', '小米相关词数', '主题', '时间顺序索引', '最大相似度', '重复次数']
# 标签: 子评论数
#
# 【特征工程】
#   提取时间特征...
#   提取文本特征...
#   合并外部特征...
#
# 【准备特征】
# 训练集特征形状: (217162, 17)
# 验证集特征形状: (27145, 17)
# 测试集特征形状: (27145, 17)
#
# 模型: LightGBM
#
# 【训练中...】
# 训练完成!
#
# 【评估结果】
#
# 数据集      RMSE       MAE        MSLE       R2
# --------------------------------------------------
# 训练集      12.1591    0.9455     0.0263     0.0632
# 验证集      10.5539    0.9555     0.0282     0.0456
# 测试集      16.3590    1.1345     0.0335     0.0157
#
# 数据集      ACP@20%      ACP@50%
# -----------------------------------
# 训练集      97.94       % 97.96       %
# 验证集      97.82       % 97.83       %
# 测试集      97.79       % 97.80       %
# 模型已保存: d:\010_CodePrograms\L\LLM_su7\results\comment_pred_lightgbm_1\model.pkl
# ...

# %%
# !python -m src --model ngboost --features all
# Out:
# ...
# 【训练+测试 - 模型: ngboost】
# ...
# 特征组: ['base', 'text', 'lda', 'density']
# 特征列 (17个): ['用户总评论数', '用户是否认证', '是否一级评论', '微博评论数', '发布小时', '发布星期', '是否工作日', '评论长度', '感叹号数', '问号数', '表情数', '话题标签有无', '小米相关词数', '主题', '时间顺序索引', '最大相似度', '重复次数']
# 标签: 子评论数
#
# 【特征工程】
#   提取时间特征...
#   提取文本特征...
#   合并外部特征...
#
# 【准备特征】
# 训练集特征形状: (217162, 17)
# 验证集特征形状: (27145, 17)
# 测试集特征形状: (27145, 17)
#
# 模型: NGBoost
#
# 【训练中...】
# 训练完成!
#
# 【评估结果】
#
# 数据集      RMSE       MAE        MSLE       R2
# --------------------------------------------------
# 训练集      7.7244     0.7879     0.0176     0.6219
# 验证集      9.4926     0.9587     0.0284     0.2279
# 测试集      16.3624    1.1563     0.0350     0.0153
#
# 数据集      ACP@20%      ACP@50%
# -----------------------------------
# 训练集      98.15       % 98.23       %
# 验证集      97.58       % 97.61       %
# 测试集      97.56       % 97.57       %
#
# 【不确定性估计】
# 数据集      NLL          LogNLL       PICP@95%     MPIW
# -------------------------------------------------------
# ...

# %%
# !python -m src --model ngboost --features all --mode test --checkpoint results/comment_pred_ngboost_4/model.pkl

# %%
# !python -m src --model bge_mini --mode test --ablation no_density --checkpoint results/bge_mini_no_density_1/model_best.pt --use_cache --batch_size 256
# Out:
# ...
# 【仅测试 - 模型: bge_mini】
# ...
# 特征组: ['base', 'text']
# 特征列 (13个): ['用户总评论数', '用户是否认证', '是否一级评论', '微博评论数', '发布小时', '发布星期', '是否工作日', '评论长度', '感叹号数', '问号数', '表情数', '话题标签有无', '小米相关词数']
# 标签: 子评论数
#
# 【特征工程】
#   提取时间特征...
#   提取文本特征...
#
# 【准备特征】
# 训练集特征形状: (217162, 13)
# 验证集特征形状: (27145, 13)
# 测试集特征形状: (27145, 13)
#
# 模型: BGE_Mini
#   冻结BGE: True
#   隐藏层大小: 256
#   Dropout: 0.1
#   Epochs: 30
#   Batch Size: 256
#   学习率: 0.0001
#   预分词缓存: d:\010_CodePrograms\L\LLM_su7\cache
#
# 结果保存目录: d:\010_CodePrograms\L\LLM_su7\results\comment_pred_bge_mini_6
#
# 【训练中...】
#
# [Mini模型] 使用设备: cuda
#   冻结BGE: True
#   使用上下文: True
#   特殊嵌入: True
# 加载BGE模型: d:\010_CodePrograms\L\LLM_su7\bge-base-zh-v1.5
# BGE权重加载完成，匹配: 200/200
# 创建数据集...
#   从缓存加载分词结果: d:\010_CodePrograms\L\LLM_su7\cache
#     加载评论文案缓存...
#     加载微博文案缓存...
#     加载根评论文案缓存...
#     加载父评论文案缓存...
#     从缓存加载特殊Token ID...
#   缓存加载完成。
#   从缓存加载分词结果: d:\010_CodePrograms\L\LLM_su7\cache
#     加载评论文案缓存...
#     加载微博文案缓存...
#     加载根评论文案缓存...
# ...
